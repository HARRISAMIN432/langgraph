# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",      
    temperature=0.7,
)

# %%
class LLMState(TypedDict):
    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:

    # extract the question from state
    question = state['question']

    # form a prompt
    prompt = f'Answer the following question {question}'

    # ask that question to the LLM
    answer = model.invoke(prompt).content

    # update the answer in the state
    state['answer'] = answer

    return state

# %%
graph = StateGraph(LLMState)

graph.add_node('llm_qa', llm_qa)

# add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

# compile
workflow = graph.compile()

# %%
# execute

intial_state = {'question': 'How far is moon from the earth?'}

final_state = workflow.invoke(intial_state)

print(final_state['answer'])
# Out:
# The distance between the Earth and the Moon is not constant because the Moon orbits the Earth in an ellipse, not a perfect circle.
#
# However, here's the breakdown:
#
# *   **Average Distance:** Approximately **384,400 kilometers (238,900 miles)**.
#
# *   **Closest Point (Perigee):** The Moon can get as close as about **363,104 kilometers (225,623 miles)**.
#
# *   **Farthest Point (Apogee):** The Moon can be as far as about **405,696 kilometers (252,088 miles)**.
#
# So, while the average is often cited, the actual distance varies throughout the lunar month.

# %%
model.invoke('How far is moon from the earth?').content
# Out:
# "The average distance from the Earth to the Moon is approximately **384,400 kilometers (238,900 miles)**.\n\nHowever, this distance isn't constant because the Moon's orbit around Earth is not a perfect circle; it's an ellipse. So, the distance varies:\n\n*   **Perigee (closest point):** About 363,104 km (225,623 miles)\n*   **Apogee (farthest point):** About 405,696 km (252,088 miles)\n\nIt takes light about 1.28 seconds to travel from the Moon to the Earth."
